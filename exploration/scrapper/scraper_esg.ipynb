# %% [markdown]
# # Packages

# %%
from scraper import (
    download_msci_esg_ratings_htmlfile,
    save_dict_to_json,
    load_dict_from_json
)

from tqdm.auto import tqdm

# %% [markdown]
# # Fixed values

# %%
DICT = {'AMZN':30, 
        'TSLA':25.3, 
        'WMT':25.3, 
        'DIS':15.7, 
        'F':23.2, 
        'PG':27.9, 
        'COST':26.3, 
        'KO':24.9, 
        'PEP':22.1,
        'XOM':41.6, 
        'CVX':36.8,
        'BP':36.0, 
        'TTE':27.1, 
        'JPM':30.1, 
        'V':16.4, 
        'MA':16.6, 
        'BAC':28.3, 
        'JNJ':23.9, 
        'PFE':18.7, 
        'MRK':22.1, 
        'ABT':25.0, 
        'UNH':15.3, 
        'GE':36.9, 
        'BA':39.4, 
        'MMM':41.0, 
        'CAT':36.3, 
        'HON':28.1, 
        'AAPL':17.2, 
        'MSFT':15.2, 
        'GOOGL':24.1, 
        'NVDA':13.5}

TICKERS = list(DICT.keys())

# %% [markdown]
# # Scrap data

# %%
# scrap data
dict_info_big={}
for ticker in tqdm(TICKERS):
    dict = download_msci_esg_ratings_htmlfile(tickers=[ticker])
    dict_info_big[ticker] = dict[ticker]
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]
# Crawling ESG Ticker: AMZN
# Cookies rejected.
# Crawling ESG Ticker: TSLA
# No 'reject all' button found for cookies or it's already rejected.
# Crawling ESG Ticker: WMT
# Cookies rejected.
# Crawling ESG Ticker: DIS
# Cookies rejected.
# Crawling ESG Ticker: F
# Cookies rejected.
# Crawling ESG Ticker: PG
# Cookies rejected.
# Crawling ESG Ticker: COST
# Cookies rejected.
# Crawling ESG Ticker: KO
# Cookies rejected.
# Crawling ESG Ticker: PEP
# Cookies rejected.
# Crawling ESG Ticker: XOM
# Cookies rejected.
# Crawling ESG Ticker: CVX
# Cookies rejected.
# Crawling ESG Ticker: BP
# Cookies rejected.
# Crawling ESG Ticker: TTE
# Cookies rejected.
# Crawling ESG Ticker: JPM
# Cookies rejected.
# Crawling ESG Ticker: V
# Cookies rejected.
# Crawling ESG Ticker: MA
# Cookies rejected.
# Crawling ESG Ticker: BAC
# Cookies rejected.
# Crawling ESG Ticker: JNJ
# Cookies rejected.
# Crawling ESG Ticker: PFE
# Cookies rejected.
# Crawling ESG Ticker: MRK
# Cookies rejected.
# Crawling ESG Ticker: ABT
# Cookies rejected.
# Crawling ESG Ticker: UNH
# Cookies rejected.
# Crawling ESG Ticker: GE
# Cookies rejected.
# Crawling ESG Ticker: BA
# Cookies rejected.
# Crawling ESG Ticker: MMM
# Cookies rejected.
# Crawling ESG Ticker: CAT
# Cookies rejected.
# Crawling ESG Ticker: HON
# Cookies rejected.
# Crawling ESG Ticker: AAPL
# Cookies rejected.
# Crawling ESG Ticker: MSFT
# Cookies rejected.
# Crawling ESG Ticker: GOOGL
# Cookies rejected.
# Crawling ESG Ticker: NVDA
# Cookies rejected.

# %%
dict_info_big
# Out:
# {'AMZN': {'esg_score_dict': {'Apr-20': 'BBB',
#    'Dec-20': 'BBB',
#    'Dec-21': 'BBB',
#    'Dec-22': 'A',
#    'Aug-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.01,
#    'B': 0.03,
#    'BB': 0.07,
#    'BBB': 0.13,
#    'A': 0.32,
#    'AA': 0.36,
#    'AAA': 0.07},
#   'industry': 'retail - consumer discretionary industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'TSLA': {'esg_score_dict': {'Apr-20': 'A',
#    'May-21': 'A',
#    'Dec-21': 'A',
#    'May-22': 'A',
#    'Jul-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.04,
#    'B': 0.2,
#    'BB': 0.14,
#    'BBB': 0.12,
#    'A': 0.31,
#    'AA': 0.12,
#    'AAA': 0.08},
#   'industry': 'automobiles industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'WMT': {'esg_score_dict': {'Jun-20': 'BBB',
#    'Dec-20': 'BB',
#    'Sep-21': 'BBB',
#    'Oct-22': 'BBB',
#    'Dec-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.02,
#    'B': 0.02,
#    'BB': 0.07,
#    'BBB': 0.14,
#    'A': 0.35,
#    'AA': 0.33,
#    'AAA': 0.07},
#   'industry': 'retail - food & staples industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'DIS': {'esg_score_dict': {'Apr-20': 'BBB',
#    'Mar-21': 'A',
#    'Feb-22': 'A',
#    'Jan-23': 'A',
#    'Jan-24': 'A'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.16,
#    'BB': 0.24,
#    'BBB': 0.22,
#    'A': 0.18,
#    'AA': 0.15,
#    'AAA': 0.01},
#   'industry': 'media & entertainment industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'F': {'esg_score_dict': {'Dec-19': 'CCC',
#    'Sep-20': 'CCC',
#    'Dec-21': 'CCC',
#    'Dec-22': 'B',
#    'Jun-23': 'B'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.07,
#    'BB': 0.19,
#    'BBB': 0.22,
#    'A': 0.04,
#    'AA': 0.19,
#    'AAA': 0.3},
#   'industry': 'textiles, apparel & luxury goods industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Green',
#    'Governance': 'Green'}},
#  'PG': {'esg_score_dict': {'Apr-19': 'BB',
#    'Apr-20': 'BB',
#    'Dec-20': 'BB',
#    'Mar-22': 'BB',
#    'Nov-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.1,
#    'B': 0.03,
#    'BB': 0.16,
#    'BBB': 0.12,
#    'A': 0.21,
#    'AA': 0.25,
#    'AAA': 0.13},
#   'industry': 'utilities industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'COST': {'esg_score_dict': {'Apr-19': 'BB',
#    'Feb-20': 'BB',
#    'Mar-21': 'BBB',
#    'Jun-22': 'A',
#    'Apr-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.02,
#    'B': 0.02,
#    'BB': 0.07,
#    'BBB': 0.14,
#    'A': 0.35,
#    'AA': 0.33,
#    'AAA': 0.07},
#   'industry': 'retail - food & staples industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'KO': {'esg_score_dict': {'Nov-19': 'AA',
#    'Dec-20': 'AA',
#    'Dec-21': 'AA',
#    'Sep-22': 'AAA',
#    'Aug-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.13,
#    'BB': 0.15,
#    'BBB': 0.07,
#    'A': 0.2,
#    'AA': 0.2,
#    'AAA': 0.11},
#   'industry': 'beverages industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Yellow',
#    'Governance': 'Yellow'}},
#  'PEP': {'esg_score_dict': {'Dec-19': 'AA',
#    'Jun-20': 'AA',
#    'Dec-21': 'AA',
#    'Dec-22': 'AA',
#    'Nov-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.13,
#    'BB': 0.15,
#    'BBB': 0.07,
#    'A': 0.2,
#    'AA': 0.2,
#    'AAA': 0.11},
#   'industry': 'beverages industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'XOM': {'esg_score_dict': {'Sep-19': 'BBB',
#    'Jul-20': 'BBB',
#    'Jun-21': 'BBB',
#    'May-22': 'BBB',
#    'May-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'CVX': {'esg_score_dict': {'Oct-19': 'BBB',
#    'Sep-20': 'BBB',
#    'Sep-21': 'BBB',
#    'Jun-22': 'A',
#    'Sep-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'BP': {'esg_score_dict': {'Aug-19': 'BBB',
#    'Aug-20': 'BBB',
#    'Nov-21': 'A',
#    'Jul-22': 'A',
#    'Jul-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'TTE': {'esg_score_dict': {'Oct-19': 'A',
#    'Sep-20': 'A',
#    'Nov-21': 'A',
#    'May-22': 'A',
#    'Aug-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'JPM': {'esg_score_dict': {'Jul-20': 'BB',
#    'Dec-20': 'BBB',
#    'Oct-21': 'A',
#    'Dec-22': 'A',
#    'Dec-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.01,
#    'B': 0.01,
#    'BB': 0.08,
#    'BBB': 0.2,
#    'A': 0.27,
#    'AA': 0.36,
#    'AAA': 0.05},
#   'industry': 'banks industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Orange'}},
#  'V': {'esg_score_dict': {'Dec-19': 'A',
#    'Mar-20': 'A',
#    'Mar-21': 'A',
#    'May-22': 'A',
#    'Jun-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.16,
#    'BBB': 0.13,
#    'A': 0.24,
#    'AA': 0.31,
#    'AAA': 0.03},
#   'industry': 'diversified financials industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'MA': {'esg_score_dict': {'May-19': 'A',
#    'May-20': 'A',
#    'Jun-21': 'A',
#    'Dec-22': 'AA',
#    'Oct-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.16,
#    'BBB': 0.13,
#    'A': 0.24,
#    'AA': 0.31,
#    'AAA': 0.03},
#   'industry': 'diversified financials industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'BAC': {'esg_score_dict': {'Jul-19': 'BB',
#    'May-20': 'BB',
#    'Feb-21': 'BBB',
#    'Jul-22': 'A',
#    'Aug-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.01,
#    'B': 0.01,
#    'BB': 0.08,
#    'BBB': 0.2,
#    'A': 0.27,
#    'AA': 0.36,
#    'AAA': 0.05},
#   'industry': 'banks industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'JNJ': {'esg_score_dict': {'Oct-19': 'BBB',
#    'Dec-20': 'BBB',
#    'Dec-21': 'BBB',
#    'Aug-22': 'A',
#    'Aug-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.16,
#    'BB': 0.17,
#    'BBB': 0.13,
#    'A': 0.25,
#    'AA': 0.25,
#    'AAA': 0.05},
#   'industry': 'pharmaceuticals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'PFE': {'esg_score_dict': {'Jun-19': 'B',
#    'Jun-20': 'B',
#    'Jun-21': 'B',
#    'Jul-22': 'A',
#    'Jun-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.16,
#    'BB': 0.17,
#    'BBB': 0.13,
#    'A': 0.25,
#    'AA': 0.25,
#    'AAA': 0.05},
#   'industry': 'pharmaceuticals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'MRK': {'esg_score_dict': {'Feb-20': 'A',
#    'Mar-21': 'BBB',
#    'Oct-21': 'A',
#    'Oct-22': 'AA',
#    'Oct-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.16,
#    'BB': 0.17,
#    'BBB': 0.13,
#    'A': 0.25,
#    'AA': 0.25,
#    'AAA': 0.05},
#   'industry': 'pharmaceuticals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'ABT': {'esg_score_dict': {'Nov-19': 'BBB',
#    'Dec-20': 'BB',
#    'Nov-21': 'BB',
#    'Aug-22': 'A',
#    'Aug-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.12,
#    'BB': 0.04,
#    'BBB': 0.21,
#    'A': 0.17,
#    'AA': 0.34,
#    'AAA': 0.13},
#   'industry': 'health care equipment & supplies industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'UNH': {'esg_score_dict': {'Sep-20': 'BB',
#    'Aug-21': 'BB',
#    'May-22': 'BBB',
#    'Aug-22': 'AA',
#    'Aug-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.02,
#    'B': 0.05,
#    'BB': 0.14,
#    'BBB': 0.14,
#    'A': 0.23,
#    'AA': 0.38,
#    'AAA': 0.04},
#   'industry': 'health care providers & services industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'GE': {'esg_score_dict': {'May-20': 'A',
#    'Dec-20': 'BB',
#    'Dec-21': 'BB',
#    'Dec-22': 'BBB',
#    'Dec-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.1,
#    'BBB': 0.31,
#    'A': 0.15,
#    'AA': 0.21,
#    'AAA': 0.1},
#   'industry': 'industrial conglomerates industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Green',
#    'Governance': 'Yellow'}},
#  'BA': {'esg_score_dict': {'Mar-20': 'BB',
#    'Dec-20': 'BB',
#    'Dec-21': 'BB',
#    'Jul-22': 'BBB',
#    'Sep-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.16,
#    'B': 0.03,
#    'BB': 0.11,
#    'BBB': 0.13,
#    'A': 0.26,
#    'AA': 0.26,
#    'AAA': 0.05},
#   'industry': 'aerospace & defense industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'MMM': {'esg_score_dict': {'Jul-19': 'AAA',
#    'Jun-20': 'AAA',
#    'Sep-21': 'AAA',
#    'Oct-22': 'AAA',
#    'Oct-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.1,
#    'BBB': 0.31,
#    'A': 0.15,
#    'AA': 0.21,
#    'AAA': 0.1},
#   'industry': 'industrial conglomerates industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'CAT': {'esg_score_dict': {'Apr-20': 'A',
#    'Aug-20': 'A',
#    'Oct-21': 'A',
#    'Nov-22': 'A',
#    'Dec-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.15,
#    'BB': 0.15,
#    'BBB': 0.13,
#    'A': 0.1,
#    'AA': 0.23,
#    'AAA': 0.1},
#   'industry': 'construction & farm machinery & heavy trucks industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'HON': {'esg_score_dict': {'Dec-19': 'BB',
#    'Dec-20': 'BB',
#    'Dec-21': 'BB',
#    'Nov-22': 'B',
#    'Nov-23': 'BB'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.13,
#    'BB': 0.19,
#    'BBB': 0.11,
#    'A': 0.26,
#    'AA': 0.11,
#    'AAA': 0.07},
#   'industry': 'electronic equipment, instruments & components industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'AAPL': {'esg_score_dict': {'Nov-19': 'A',
#    'Dec-20': 'BBB',
#    'Dec-21': 'A',
#    'Nov-22': 'BBB',
#    'Dec-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.16,
#    'BB': 0.2,
#    'BBB': 0.11,
#    'A': 0.16,
#    'AA': 0.22,
#    'AAA': 0.09},
#   'industry': 'technology hardware, storage & peripherals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'MSFT': {'esg_score_dict': {'Mar-19': 'AAA',
#    'Feb-20': 'AAA',
#    'Mar-21': 'AAA',
#    'Feb-22': 'AAA',
#    'Feb-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.06,
#    'BB': 0.08,
#    'BBB': 0.17,
#    'A': 0.21,
#    'AA': 0.33,
#    'AAA': 0.11},
#   'industry': 'software & services industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Yellow'}},
#  'GOOGL': {'esg_score_dict': {'Mar-20': 'AA',
#    'Nov-20': 'BBB',
#    'Jun-21': 'BBB',
#    'Jul-22': 'BBB',
#    'Jul-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.17,
#    'BB': 0.25,
#    'BBB': 0.17,
#    'A': 0.21,
#    'AA': 0.17,
#    'AAA': 0.04},
#   'industry': 'interactive media & services industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'NVDA': {'esg_score_dict': {'Feb-20': 'AAA',
#    'Oct-20': 'AAA',
#    'Oct-21': 'AAA',
#    'Sep-22': 'AAA',
#    'May-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.19,
#    'B': 0.23,
#    'BB': 0.15,
#    'BBB': 0.08,
#    'A': 0.16,
#    'AA': 0.11,
#    'AAA': 0.08},
#   'industry': 'semiconductors & semiconductor equipment industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Green',
#    'Governance': 'Green'}}}

# %% [markdown]
# # Save data

# %%
# Save data in this folder
save_dict_to_json(dict_info_big, './esg_data_scrapped/msci_esg_ratings.json')
# Save data in data folder
save_dict_to_json(dict_info_big, '../../data/msci_esg_ratings.json')
# Out:
# Dictionary saved to ../../data/msci_esg_ratings.json.

# %% [markdown]
# # Load data

# %%
dict_info_big = load_dict_from_json('./esg_data_scrapped/msci_esg_ratings.json')

# %%
dict_info_big
# Out:
# {'AMZN': {'esg_score_dict': {'Apr-20': 'BBB',
#    'Dec-20': 'BBB',
#    'Dec-21': 'BBB',
#    'Dec-22': 'A',
#    'Aug-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.01,
#    'B': 0.03,
#    'BB': 0.07,
#    'BBB': 0.13,
#    'A': 0.32,
#    'AA': 0.36,
#    'AAA': 0.07},
#   'industry': 'retail - consumer discretionary industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'TSLA': {'esg_score_dict': {'Apr-20': 'A',
#    'May-21': 'A',
#    'Dec-21': 'A',
#    'May-22': 'A',
#    'Jul-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.04,
#    'B': 0.2,
#    'BB': 0.14,
#    'BBB': 0.12,
#    'A': 0.31,
#    'AA': 0.12,
#    'AAA': 0.08},
#   'industry': 'automobiles industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'WMT': {'esg_score_dict': {'Jun-20': 'BBB',
#    'Dec-20': 'BB',
#    'Sep-21': 'BBB',
#    'Oct-22': 'BBB',
#    'Dec-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.02,
#    'B': 0.02,
#    'BB': 0.07,
#    'BBB': 0.14,
#    'A': 0.35,
#    'AA': 0.33,
#    'AAA': 0.07},
#   'industry': 'retail - food & staples industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'DIS': {'esg_score_dict': {'Apr-20': 'BBB',
#    'Mar-21': 'A',
#    'Feb-22': 'A',
#    'Jan-23': 'A',
#    'Jan-24': 'A'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.16,
#    'BB': 0.24,
#    'BBB': 0.22,
#    'A': 0.18,
#    'AA': 0.15,
#    'AAA': 0.01},
#   'industry': 'media & entertainment industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'F': {'esg_score_dict': {'Dec-19': 'CCC',
#    'Sep-20': 'CCC',
#    'Dec-21': 'CCC',
#    'Dec-22': 'B',
#    'Jun-23': 'B'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.07,
#    'BB': 0.19,
#    'BBB': 0.22,
#    'A': 0.04,
#    'AA': 0.19,
#    'AAA': 0.3},
#   'industry': 'textiles, apparel & luxury goods industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Green',
#    'Governance': 'Green'}},
#  'PG': {'esg_score_dict': {'Apr-19': 'BB',
#    'Apr-20': 'BB',
#    'Dec-20': 'BB',
#    'Mar-22': 'BB',
#    'Nov-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.1,
#    'B': 0.03,
#    'BB': 0.16,
#    'BBB': 0.12,
#    'A': 0.21,
#    'AA': 0.25,
#    'AAA': 0.13},
#   'industry': 'utilities industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'COST': {'esg_score_dict': {'Apr-19': 'BB',
#    'Feb-20': 'BB',
#    'Mar-21': 'BBB',
#    'Jun-22': 'A',
#    'Apr-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.02,
#    'B': 0.02,
#    'BB': 0.07,
#    'BBB': 0.14,
#    'A': 0.35,
#    'AA': 0.33,
#    'AAA': 0.07},
#   'industry': 'retail - food & staples industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'KO': {'esg_score_dict': {'Nov-19': 'AA',
#    'Dec-20': 'AA',
#    'Dec-21': 'AA',
#    'Sep-22': 'AAA',
#    'Aug-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.13,
#    'BB': 0.15,
#    'BBB': 0.07,
#    'A': 0.2,
#    'AA': 0.2,
#    'AAA': 0.11},
#   'industry': 'beverages industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Yellow',
#    'Governance': 'Yellow'}},
#  'PEP': {'esg_score_dict': {'Dec-19': 'AA',
#    'Jun-20': 'AA',
#    'Dec-21': 'AA',
#    'Dec-22': 'AA',
#    'Nov-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.13,
#    'BB': 0.15,
#    'BBB': 0.07,
#    'A': 0.2,
#    'AA': 0.2,
#    'AAA': 0.11},
#   'industry': 'beverages industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'XOM': {'esg_score_dict': {'Sep-19': 'BBB',
#    'Jul-20': 'BBB',
#    'Jun-21': 'BBB',
#    'May-22': 'BBB',
#    'May-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'CVX': {'esg_score_dict': {'Oct-19': 'BBB',
#    'Sep-20': 'BBB',
#    'Sep-21': 'BBB',
#    'Jun-22': 'A',
#    'Sep-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'BP': {'esg_score_dict': {'Aug-19': 'BBB',
#    'Aug-20': 'BBB',
#    'Nov-21': 'A',
#    'Jul-22': 'A',
#    'Jul-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Orange',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'TTE': {'esg_score_dict': {'Oct-19': 'A',
#    'Sep-20': 'A',
#    'Nov-21': 'A',
#    'May-22': 'A',
#    'Aug-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.09,
#    'BB': 0.14,
#    'BBB': 0.05,
#    'A': 0.36,
#    'AA': 0.18,
#    'AAA': 0.14},
#   'industry': 'integrated oil & gas industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'JPM': {'esg_score_dict': {'Jul-20': 'BB',
#    'Dec-20': 'BBB',
#    'Oct-21': 'A',
#    'Dec-22': 'A',
#    'Dec-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.01,
#    'B': 0.01,
#    'BB': 0.08,
#    'BBB': 0.2,
#    'A': 0.27,
#    'AA': 0.36,
#    'AAA': 0.05},
#   'industry': 'banks industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Orange'}},
#  'V': {'esg_score_dict': {'Dec-19': 'A',
#    'Mar-20': 'A',
#    'Mar-21': 'A',
#    'May-22': 'A',
#    'Jun-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.16,
#    'BBB': 0.13,
#    'A': 0.24,
#    'AA': 0.31,
#    'AAA': 0.03},
#   'industry': 'diversified financials industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'MA': {'esg_score_dict': {'May-19': 'A',
#    'May-20': 'A',
#    'Jun-21': 'A',
#    'Dec-22': 'AA',
#    'Oct-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.16,
#    'BBB': 0.13,
#    'A': 0.24,
#    'AA': 0.31,
#    'AAA': 0.03},
#   'industry': 'diversified financials industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'BAC': {'esg_score_dict': {'Jul-19': 'BB',
#    'May-20': 'BB',
#    'Feb-21': 'BBB',
#    'Jul-22': 'A',
#    'Aug-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.01,
#    'B': 0.01,
#    'BB': 0.08,
#    'BBB': 0.2,
#    'A': 0.27,
#    'AA': 0.36,
#    'AAA': 0.05},
#   'industry': 'banks industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'JNJ': {'esg_score_dict': {'Oct-19': 'BBB',
#    'Dec-20': 'BBB',
#    'Dec-21': 'BBB',
#    'Aug-22': 'A',
#    'Aug-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.16,
#    'BB': 0.17,
#    'BBB': 0.13,
#    'A': 0.25,
#    'AA': 0.25,
#    'AAA': 0.05},
#   'industry': 'pharmaceuticals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'PFE': {'esg_score_dict': {'Jun-19': 'B',
#    'Jun-20': 'B',
#    'Jun-21': 'B',
#    'Jul-22': 'A',
#    'Jun-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.16,
#    'BB': 0.17,
#    'BBB': 0.13,
#    'A': 0.25,
#    'AA': 0.25,
#    'AAA': 0.05},
#   'industry': 'pharmaceuticals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'MRK': {'esg_score_dict': {'Feb-20': 'A',
#    'Mar-21': 'BBB',
#    'Oct-21': 'A',
#    'Oct-22': 'AA',
#    'Oct-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.16,
#    'BB': 0.17,
#    'BBB': 0.13,
#    'A': 0.25,
#    'AA': 0.25,
#    'AAA': 0.05},
#   'industry': 'pharmaceuticals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'ABT': {'esg_score_dict': {'Nov-19': 'BBB',
#    'Dec-20': 'BB',
#    'Nov-21': 'BB',
#    'Aug-22': 'A',
#    'Aug-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.12,
#    'BB': 0.04,
#    'BBB': 0.21,
#    'A': 0.17,
#    'AA': 0.34,
#    'AAA': 0.13},
#   'industry': 'health care equipment & supplies industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'UNH': {'esg_score_dict': {'Sep-20': 'BB',
#    'Aug-21': 'BB',
#    'May-22': 'BBB',
#    'Aug-22': 'AA',
#    'Aug-23': 'AA'},
#   'industry_scores_dict': {'CCC': 0.02,
#    'B': 0.05,
#    'BB': 0.14,
#    'BBB': 0.14,
#    'A': 0.23,
#    'AA': 0.38,
#    'AAA': 0.04},
#   'industry': 'health care providers & services industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Orange'}},
#  'GE': {'esg_score_dict': {'May-20': 'A',
#    'Dec-20': 'BB',
#    'Dec-21': 'BB',
#    'Dec-22': 'BBB',
#    'Dec-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.1,
#    'BBB': 0.31,
#    'A': 0.15,
#    'AA': 0.21,
#    'AAA': 0.1},
#   'industry': 'industrial conglomerates industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Green',
#    'Governance': 'Yellow'}},
#  'BA': {'esg_score_dict': {'Mar-20': 'BB',
#    'Dec-20': 'BB',
#    'Dec-21': 'BB',
#    'Jul-22': 'BBB',
#    'Sep-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.16,
#    'B': 0.03,
#    'BB': 0.11,
#    'BBB': 0.13,
#    'A': 0.26,
#    'AA': 0.26,
#    'AAA': 0.05},
#   'industry': 'aerospace & defense industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'MMM': {'esg_score_dict': {'Jul-19': 'AAA',
#    'Jun-20': 'AAA',
#    'Sep-21': 'AAA',
#    'Oct-22': 'AAA',
#    'Oct-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.1,
#    'BB': 0.1,
#    'BBB': 0.31,
#    'A': 0.15,
#    'AA': 0.21,
#    'AAA': 0.1},
#   'industry': 'industrial conglomerates industry',
#   'controversy_info': {'Environment': 'Yellow',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'CAT': {'esg_score_dict': {'Apr-20': 'A',
#    'Aug-20': 'A',
#    'Oct-21': 'A',
#    'Nov-22': 'A',
#    'Dec-23': 'A'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.15,
#    'BB': 0.15,
#    'BBB': 0.13,
#    'A': 0.1,
#    'AA': 0.23,
#    'AAA': 0.1},
#   'industry': 'construction & farm machinery & heavy trucks industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'HON': {'esg_score_dict': {'Dec-19': 'BB',
#    'Dec-20': 'BB',
#    'Dec-21': 'BB',
#    'Nov-22': 'B',
#    'Nov-23': 'BB'},
#   'industry_scores_dict': {'CCC': 0.13,
#    'B': 0.13,
#    'BB': 0.19,
#    'BBB': 0.11,
#    'A': 0.26,
#    'AA': 0.11,
#    'AAA': 0.07},
#   'industry': 'electronic equipment, instruments & components industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Green'}},
#  'AAPL': {'esg_score_dict': {'Nov-19': 'A',
#    'Dec-20': 'BBB',
#    'Dec-21': 'A',
#    'Nov-22': 'BBB',
#    'Dec-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.05,
#    'B': 0.16,
#    'BB': 0.2,
#    'BBB': 0.11,
#    'A': 0.16,
#    'AA': 0.22,
#    'AAA': 0.09},
#   'industry': 'technology hardware, storage & peripherals industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Orange',
#    'Governance': 'Yellow'}},
#  'MSFT': {'esg_score_dict': {'Mar-19': 'AAA',
#    'Feb-20': 'AAA',
#    'Mar-21': 'AAA',
#    'Feb-22': 'AAA',
#    'Feb-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.03,
#    'B': 0.06,
#    'BB': 0.08,
#    'BBB': 0.17,
#    'A': 0.21,
#    'AA': 0.33,
#    'AAA': 0.11},
#   'industry': 'software & services industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Yellow'}},
#  'GOOGL': {'esg_score_dict': {'Mar-20': 'AA',
#    'Nov-20': 'BBB',
#    'Jun-21': 'BBB',
#    'Jul-22': 'BBB',
#    'Jul-23': 'BBB'},
#   'industry_scores_dict': {'CCC': 0.0,
#    'B': 0.17,
#    'BB': 0.25,
#    'BBB': 0.17,
#    'A': 0.21,
#    'AA': 0.17,
#    'AAA': 0.04},
#   'industry': 'interactive media & services industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Yellow',
#    'Governance': 'Green'}},
#  'NVDA': {'esg_score_dict': {'Feb-20': 'AAA',
#    'Oct-20': 'AAA',
#    'Oct-21': 'AAA',
#    'Sep-22': 'AAA',
#    'May-23': 'AAA'},
#   'industry_scores_dict': {'CCC': 0.19,
#    'B': 0.23,
#    'BB': 0.15,
#    'BBB': 0.08,
#    'A': 0.16,
#    'AA': 0.11,
#    'AAA': 0.08},
#   'industry': 'semiconductors & semiconductor equipment industry',
#   'controversy_info': {'Environment': 'Green',
#    'Social': 'Green',
#    'Governance': 'Green'}}}
